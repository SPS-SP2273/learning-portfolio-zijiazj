# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ### Exercise 1 (Tidying a collaboration)

# %% [markdown]
# You are a member of an international team analysing environmental pollution. The project involves ten cities: Cairo, Dhaka, Jakarta, Karachi, Manila, Melbourne, Osaka, Shanghai, Singapore, and Tokyo.
#
# Your task is to process and organise data from various environmental measurements. The provided zip file, os-collaboration-exercise-data.zip, contains all relevant data files for the past year.

# %% [markdown]
# **Things to note**
#
# Data Files: Each data file is named in the format month-date_city.txt (e.g., may-10_singapore.txt).
#
# Data Collection: Data was recorded sporadically; not all days of each month have corresponding data files. The dates of data collection vary across the cities.
#
# Exclusion of Files: Ignore any non-text files, such as those in .pdf, .png, or .jpg formats.

# %% [markdown]
# ## Task 1

# %% [markdown]
# - We like to convert the filename to a more useful numerical format. Specifically, we want to convert month-date-city.txt. (i.e. may-10-singapore.txt) to a mm-dd-city.txt (i.e. 05-10-singapore.txt) format.
#
# - Using the following dictionary (or otherwise), write a snippet of Python code to convert 'oct-08_singapore.txt' to 10-08-singapore.txt.

# %%
num_month = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
old_filename = 'oct-08_singapore.txt'
month, day_location = old_filename.split('-')
month_number = num_month[month]
day, location = day_location.split('_')
new_file_name = f'{month_number}-{day}-{location}'

print(new_file_name)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ## Task 2

# %% [markdown]
# Incorporate your previous code into a function named rename_my_file(old_file_name) that accepts the old filename as the argument and returns the new file name.

# %%
def rename_my_file(old_file_name):
    month, day_location = old_file_name.split('-')
    month_number = num_month[month]
    day, location = day_location.split('_')
    new_file_name = f'{month_number}-{day}-{location}'
    return new_file_name

rename_my_file('feb-20_Singapore.txt')
# Out:
# '02-20-Singapore.txt'

# %% [markdown]
# ## Task 3

# %% [markdown]
# - Use a for loop to apply the function rename_my_file() to the file list below.
# - Print out your progress in the form old-file-name ----> new-file-name

# %%
example_files = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

def rename_my_file(old_file_name):
    month, day_location = old_file_name.split('-')
    month_number = num_month[month]
    day, location = day_location.split('_')
    new_file_name = f'{month_number}-{day}-{location}'
    return new_file_name


for old_name in example_files:
    print(f'{old_name}-----> {rename_my_file(old_name)}')
# Out:
# oct-08_singapore.txt-----> 10-08-singapore.txt
# jul-10_cairo.txt-----> 07-10-cairo.txt
# may-15_dhaka.txt-----> 05-15-dhaka.txt
# may-13_cairo.txt-----> 05-13-cairo.txt
# oct-21_cairo.txt-----> 10-21-cairo.txt
# jan-10_singapore.txt-----> 01-10-singapore.txt
# jun-20_tokyo.txt-----> 06-20-tokyo.txt
# aug-06_jakarta.txt-----> 08-06-jakarta.txt
# dec-21_karachi.txt-----> 12-21-karachi.txt
# jan-01_tokyo.txt-----> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4

# %% [markdown]
# - With the help of glob, use rename_my_file() to rename all the .txt files in the folder.
#
# - Note that you might have to adjust your function rename_my_file() to accommodate the already renamed files.

# %%
import glob

# %%
import os

# %%
def rename_my_file(old_file_name):
    month, day_location = old_file_name.split('-')
    month_number = num_month[month]
    day, location = day_location.split('_')
    new_file_name = f'{month_number}-{day}-{location}'
    return new_file_name

files = glob.glob('*/*txt')
for old_name in files:
    clean_name = old_name.split(os.path.sep)[-1]
    new_name = f'data{os.path.sep}{rename_my_file(clean_name)}'
    print(new_name)
    os.rename(old_name, new_name) # Address of the old, new files
# Out:
# data\04-01-melbourne.txt
# data\04-01-shanghai.txt
# data\04-01-singapore.txt
# data\04-02-cairo.txt
# data\04-02-jakarta.txt
# data\04-02-karachi.txt
# data\04-02-shanghai.txt
# data\04-03-manila.txt
# data\04-03-osaka.txt
# data\04-03-singapore.txt
# data\04-03-tokyo.txt
# data\04-04-manila.txt
# data\04-04-melbourne.txt
# data\04-04-shanghai.txt
# data\04-04-singapore.txt
# data\04-05-karachi.txt
# data\04-05-melbourne.txt
# data\04-05-shanghai.txt
# data\04-05-singapore.txt
# data\04-06-cairo.txt
# data\04-06-jakarta.txt
# data\04-06-karachi.txt
# data\04-06-manila.txt
# data\04-07-cairo.txt
# data\04-07-manila.txt
# data\04-07-melbourne.txt
# data\04-07-osaka.txt
# data\04-07-singapore.txt
# data\04-07-tokyo.txt
# data\04-08-shanghai.txt
# data\04-10-cairo.txt
# data\04-10-manila.txt
# data\04-10-melbourne.txt
# data\04-10-shanghai.txt
# data\04-10-singapore.txt
# data\04-10-tokyo.txt
# data\04-11-melbourne.txt
# data\04-11-shanghai.txt
# data\04-11-tokyo.txt
# ...

# %% [markdown]
# ## Task 5

# %% [markdown]
# Use a for loop to create a folder for each city.

# %%
city = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
import os

# %%
for name in city:
    city_path = os.path.join('data', name) 
    print(f'Creating {city_path}') 
    os.mkdir(city_path)
# Out:
# Creating data\Cairo
# Creating data\Dhaka
# Creating data\Jakarta
# Creating data\Karachi
# Creating data\Manila
# Creating data\Melbourne
# Creating data\Osaka
# Creating data\Shanghai
# Creating data\Singapore
# Creating data\Tokyo

# %% [markdown]
# ## Task 6

# %% [markdown]
# - Use glob to list all the files from Cairo.
# - Now use a for loop and shutil.copy() to **copy** all the files related to Cairo to the corresponding folder you created.

# %%
import shutil

# %%
C_city = glob.glob('*/*Cairo.*')
print(C_city)

for i in C_city:
    new_destination = os.path.join('data','Cairo')
    shutil.copy(i, new_destination)
# Out:
# ['data\\01-02-cairo.txt', 'data\\01-03-cairo.txt', 'data\\01-04-cairo.txt', 'data\\01-05-cairo.txt', 'data\\01-07-cairo.txt', 'data\\01-08-cairo.txt', 'data\\01-09-cairo.txt', 'data\\01-11-cairo.txt', 'data\\01-12-cairo.txt', 'data\\01-13-cairo.txt', 'data\\01-15-cairo.txt', 'data\\01-16-cairo.txt', 'data\\01-19-cairo.txt', 'data\\01-20-cairo.txt', 'data\\01-21-cairo.txt', 'data\\01-23-cairo.txt', 'data\\01-27-cairo.txt', 'data\\01-30-cairo.txt', 'data\\02-10-cairo.txt', 'data\\02-17-cairo.txt', 'data\\02-20-cairo.txt', 'data\\02-22-cairo.txt', 'data\\02-25-cairo.txt', 'data\\02-26-cairo.txt', 'data\\03-05-cairo.txt', 'data\\03-06-cairo.txt', 'data\\03-12-cairo.txt', 'data\\03-14-cairo.txt', 'data\\03-19-cairo.txt', 'data\\03-24-cairo.txt', 'data\\04-02-cairo.txt', 'data\\04-06-cairo.txt', 'data\\04-07-cairo.txt', 'data\\04-10-cairo.txt', 'data\\04-12-cairo.txt', 'data\\04-13-cairo.txt', 'data\\04-14-cairo.txt', 'data\\04-15-cairo.txt', 'data\\04-17-cairo.txt', 'data\\04-20-cairo.txt
# ...

# %% [markdown]
# ## Task 7

# %% [markdown]
# Tweak your code to move all the files to the corresponding folders of all the cities.

# %%
city = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for new_city in city:
        j = glob.glob(f'data/*{new_city}.*')  
        for i in j:
            new_destination = os.path.join('data', new_city)
            shutil.move(i, new_destination)

# %% [markdown]
# ## Additional Footnote:

# %% [markdown]
# Alternative solutions from ChatGPT

# %%
import os

# Dictionary mapping month abbreviations to numeric representation
num_month = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

# Directory containing the files
directory = os.path.join('os-collaboration-exercise-data')

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        # Split the filename into its components (month, date_city)
        month, date_city = filename.split('-')

        # Convert the month abbreviation to its numeric representation
        month_numeric = num_month.get(month.lower(), '00')  # Default to '00' if month is not found

        # Construct the new file name in the desired format
        new_filename = f"{month_numeric}-{date_city}"

        # Rename the file
        os.rename(os.path.join(directory, filename), os.path.join(directory, new_filename))

# %% [markdown]
# Reverse the effect of the above code

# %%
# Reverse dictionary mapping numeric month representations to month abbreviations
month_num = {
    '01': 'jan', '02': 'feb', '03': 'mar',
    '04': 'apr', '05': 'may', '06': 'jun',
    '07': 'jul', '08': 'aug', '09': 'sep',
    '10': 'oct', '11': 'nov', '12': 'dec'
}

# Directory containing the files
directory = os.path.join('os-collaboration-exercise-data')

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        # Split the filename into its components (month, date, and city)
        month_numeric, date_city = filename.split('-')

        # Convert the numeric month representation to its abbreviation
        month_abbreviation = month_num.get(month_numeric, 'unk')  # Default to 'unk' if numeric month is not found

        # Construct the original file name in the desired format
        original_filename = f"{month_abbreviation}-{date_city}"

        # Rename the file
        os.rename(os.path.join(directory, filename), os.path.join(directory, original_filename))
